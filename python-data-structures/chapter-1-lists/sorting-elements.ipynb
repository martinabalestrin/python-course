# %% [markdown]
# ##### Sorting a List In-Place with `sort()`

# %%
files = ['log.txt', 'config.txt', 'error.txt']
temps = [18.5, 21.0, 19.8, 23.1]

# Sort from A to Z, modifies original list
files.sort()
print(files)
# Sort in ascending order
temps.sort()
print(temps)

# Sort from Z to A
files.sort(reverse=True)
print(files)
# Sort in descending order
temps.sort(reverse=True)
print(temps)
# Out:
# ['config.txt', 'error.txt', 'log.txt']
# [18.5, 19.8, 21.0, 23.1]
# ['log.txt', 'error.txt', 'config.txt']
# [23.1, 21.0, 19.8, 18.5]

# %% [markdown]
# ##### Creating a Sorted Copy with `sorted()`

# %%
# Preserve original order of priorities
priorities = [3, 2, 1]

# Create a new sorted version
sorted_priorities = sorted(priorities)
# Or in descending order
# sorted_priorities = sorted(priorities, reverse=True)

# This can be used to other methods of containers

print(sorted_priorities)
print(priorities)
# Out:
# [1, 2, 3]
# [3, 2, 1]

# %% [markdown]
# ##### Flipping the List Order

# %%
# Lof o events, most recent last
events = ['Start', 'Load', 'Process', 'Finish']

# Reverse the list to show most recent first
events.reverse()

print(events)
# Out:
# ['Finish', 'Process', 'Load', 'Start']
