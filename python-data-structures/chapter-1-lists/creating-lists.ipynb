# %% [markdown]
# ##### Creating Lists

# %%
# Empty Lists
empty_list =[]

# %%
# Homogeneous List
houly_temperatures = [21.5, 22.0, 22.3, 21.8]
print("Temperatures:", houly_temperatures)
print("List length:", len(houly_temperatures))
# Out:
# Temperatures: [21.5, 22.0, 22.3, 21.8]
# List length: 4

# %%
# Heterogeneous List
file_info = ["report.pdf", 2.4, True]
print("File info:", file_info)
print("List length:", len(file_info))
# Out:
# File info: ['report.pdf', 2.4, True]
# List length: 3
