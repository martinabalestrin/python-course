# %% [markdown]
# ##### Iterating over List Elements

# %%
# A list of instruments
instruments = ['guitar', 'piano', 'drums']

for instrument in instruments:
    print('I can play the', instrument)
# Out:
# I can play the guitar
# I can play the piano
# I can play the drums

# %% [markdown]
# ##### Using `enumerate()` to Loop with Index and Value

# %%
# List of items in a delivery package
package_contents = ['Keyboard', 'Mouse', 'Moitor']

# Label each item with its position
for i, item in enumerate(package_contents, 1):
    # First variable is the index + 1, second is the value of the index in the list
    print(f'Item {i}: {item}') # Using F String
# Out:
# Item 1: Keyboard
# Item 2: Mouse
# Item 3: Moitor

# %% [markdown]
# ##### Looping Over Nested Lists

# %%
# Nested Lists
matrix = [
    [1,2,3],
    [4,5,6]
]

# Print each row of the matrix
for row in matrix:
    print('Row:', row
    )

# Print every element in the matrix, row by row
for row in matrix:
    for value in row:
        print('Value:', value)
# Out:
# Row: [1, 2, 3]
# Row: [4, 5, 6]
# Value: 1
# Value: 2
# Value: 3
# Value: 4
# Value: 5
# Value: 6
